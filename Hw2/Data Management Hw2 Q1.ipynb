# %%
import numpy as np
import pandas as pd

# %%
data_2020_1 = pd.read_csv("January 2020 15-min Rain Data.csv")
data_2020_2 = pd.read_csv("February 2020 15-min Rain Data.csv")
data_2020_3 = pd.read_csv("March 2020 15-min Rain Data.csv")
data_2020_4 = pd.read_csv("April 2020 15-min Rain Data.csv")
data_2020_5 = pd.read_csv("May 2020 15-min Rain Data.csv")
data_2020_6 = pd.read_csv("June 2020 15-min Rain Data.csv")
data_2020_7 = pd.read_csv("July 2020 15-min Rain Data.csv")
data_2020_8 = pd.read_csv("August 2020 15-min Rain Data.csv")
data_2020_9 = pd.read_csv("September 2020 15-min data.csv")
data_2020_10 = pd.read_csv("October 2020 15-min data revised.csv")
data_2020_11= pd.read_csv("November 2020 15-min data.csv")
data_2020_12= pd.read_csv("December 2020 15-min data.csv")
data_2019_12 = pd.read_csv("December 2019 15-min Rain Data.csv")
data_2019_11 = pd.read_csv("November 2019 15-min Rain Data.csv")

data_2021_1 = pd.read_csv("January 2021 15-min data.csv")
data_2021_2 = pd.read_csv("February 2021 15-min data.csv")
data_2021_3 = pd.read_csv("March 2021 15-min data.csv")
data_2021 = pd.read_csv("rainfall (1).csv")

# %%
result = pd.concat([
                    data_2019_11,data_2019_12,
        data_2020_1,data_2020_2,data_2020_3,data_2020_4,data_2020_5,data_2020_6,data_2020_7,data_2020_8,data_2020_9,data_2020_10,data_2020_11
       ,data_2020_12,
        data_2021_1,data_2021_2,data_2021_3
                   ])
result
# Out:
#                  Date  Perry North  ALCOSAN  Shaler  Kennedy Twp.  \
# 0       11/13/19 0:15         0.00     0.00     0.0          0.00
# 1       11/13/19 0:15         0.00     0.00     0.0          0.00
# 2       11/13/19 0:30         0.00     0.00     0.0          0.00
# 3       11/13/19 0:45         0.00     0.00     0.0          0.00
# 4       11/13/19 1:00         0.00     0.00     0.0          0.00
# ...               ...          ...      ...     ...           ...
# 2971  3/31/2021 22:45         0.01     0.01     0.0          0.00
# 2972  3/31/2021 23:00         0.01     0.00     0.0          0.01
# 2973  3/31/2021 23:15         0.00     0.00     0.0          0.00
# 2974  3/31/2021 23:30         0.00     0.00     0.0          0.00
# 2975  3/31/2021 23:45         0.00     0.00     0.0          0.00
#
#       Upper St. Clair  Carnegie  Greentree  Lawrenceville  \
# 0                0.00      0.00        0.0            0.0
# ...

# %%
data_2021
# Out:
#                                                       ts    val src      id  \
# 0      2021-04-01T00:00:00-04:00/2021-04-01T01:00:00-...  0.002   R  149138
# 1      2021-04-01T01:00:00-04:00/2021-04-01T02:00:00-...  0.013   R  149138
# 2      2021-04-01T02:00:00-04:00/2021-04-01T03:00:00-...  0.000   R  149138
# 3      2021-04-01T03:00:00-04:00/2021-04-01T04:00:00-...  0.000   R  149138
# 4      2021-04-01T04:00:00-04:00/2021-04-01T05:00:00-...  0.000   R  149138
# ...                                                  ...    ...  ..     ...
# 15381  2021-11-01T07:00:00-04:00/2021-11-01T08:00:00-...  0.000   G       9
# 15382  2021-11-01T08:00:00-04:00/2021-11-01T09:00:00-...  0.000   G       9
# 15383  2021-11-01T09:00:00-04:00/2021-11-01T10:00:00-...  0.000   G       9
# 15384  2021-11-01T10:00:00-04:00/2021-11-01T11:00:00-...  0.000   G       9
# 15385  2021-11-01T11:00:00-04:00/2021-11-01T12:00:00-...  0.000   G       9
#
#         type
# 0      pixel
# 1      pixel
# ...

# %%
result_hourly.iloc[112032]
# Out:
# Perry North                 0.0
# ALCOSAN                     0.0
# Shaler                      0.0
# Kennedy Twp.                0.0
# Upper St. Clair             0.0
# Carnegie                    0.0
# Greentree                   0.0
# Lawrenceville               0.0
# University of Pittsburgh    0.0
# Highland Park               0.0
# Nine Mile Run               0.0
# Baldwin                     0.0
# Braddock                    0.0
# Churchill                   0.0
# Trafford                    0.0
# Castle Shannon              0.0
# Bridgeville                 0.0
# Oakdale                     0.0
# Penn Hills North            0.0
# Penn Hills South            0.0
# Moon Twp                    0.0
# North Fayette               0.0
# Findlay                     0.0
# Pleasant Hills              0.0
# White Oak                   0.0
# Elizabeth Twp.              0.0
# Marshall                    0.0
# Plum                        0.0
# Bell Acres                  0.0
# ...

# %%
result['Date'] = result['Date'].astype('datetime64')
result = result.sort_values(by="Date")
result = result.set_index("Date")
result_hourly = result.resample("1H").sum()

# %%
result_hourly
# Out:
#                      Perry North  ALCOSAN  Shaler  Kennedy Twp.  \
# Date
# 2007-01-20 00:00:00         0.00     0.00    0.00          0.00
# 2007-01-20 01:00:00         0.00     0.00    0.00          0.00
# 2007-01-20 02:00:00         0.00     0.00    0.00          0.00
# 2007-01-20 03:00:00         0.00     0.00    0.00          0.00
# 2007-01-20 04:00:00         0.00     0.00    0.00          0.00
# ...                          ...      ...     ...           ...
# 2021-03-31 19:00:00         0.00     0.00    0.00          0.00
# 2021-03-31 20:00:00         0.00     0.00    0.00          0.00
# 2021-03-31 21:00:00         0.00     0.01    0.02          0.00
# 2021-03-31 22:00:00         0.02     0.03    0.02          0.03
# 2021-03-31 23:00:00         0.01     0.00    0.00          0.01
#
#                      Upper St. Clair  Carnegie  Greentree  Lawrenceville  \
# Date
# 2007-01-20 00:00:00             0.00      0.00        0.0           0.00
# ...

# %%
hour_daily = result_hourly.iloc[112032:,:]

# %%
hour_daily
# Out:
#                      Perry North  ALCOSAN  Shaler  Kennedy Twp.  \
# Date
# 2019-11-01 00:00:00         0.00     0.00    0.00          0.00
# 2019-11-01 01:00:00         0.00     0.00    0.00          0.00
# 2019-11-01 02:00:00         0.00     0.00    0.00          0.00
# 2019-11-01 03:00:00         0.00     0.00    0.00          0.00
# 2019-11-01 04:00:00         0.00     0.00    0.00          0.00
# ...                          ...      ...     ...           ...
# 2021-03-31 19:00:00         0.00     0.00    0.00          0.00
# 2021-03-31 20:00:00         0.00     0.00    0.00          0.00
# 2021-03-31 21:00:00         0.00     0.01    0.02          0.00
# 2021-03-31 22:00:00         0.02     0.03    0.02          0.03
# 2021-03-31 23:00:00         0.01     0.00    0.00          0.01
#
#                      Upper St. Clair  Carnegie  Greentree  Lawrenceville  \
# Date
# 2019-11-01 00:00:00             0.00      0.00        0.0           0.00
# ...

# %%
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
# %matplotlib inline

fig = figure(figsize = (9,8),dpi = 80)
x = np.array(hour_daily.append(df).index)
y = hour_daily.append(df)['University of Pittsburgh']
y[y<0]=0
y = np.array(y)
plt.scatter(x,y,s=1)
plt.xlabel("Date")
plt.ylabel("Rainfall(inch)")
plt.title("Rainfall detected by Gauge University of Pittsburgh during the past 2 years")
plt.show()
fig.savefig("rainfall.png")

# %%
hour_daily
# Out:
#                      University of Pittsburgh  Highland Park  Nine Mile Run  \
# Date
# 2019-11-01 00:00:00                      0.00           0.00           0.00
# 2019-11-01 01:00:00                      0.00           0.00           0.00
# 2019-11-01 02:00:00                      0.00           0.00           0.00
# 2019-11-01 03:00:00                      0.00           0.00           0.00
# 2019-11-01 04:00:00                      0.00           0.00           0.00
# ...                                       ...            ...            ...
# 2021-03-31 19:00:00                      0.00           0.00           0.00
# 2021-03-31 20:00:00                      0.00           0.00           0.00
# 2021-03-31 21:00:00                      0.04           0.04           0.02
# 2021-03-31 22:00:00                      0.03           0.03           0.06
# 2021-03-31 23:00:00                      0.01           0.00           0.00
#
# ...

# %%
data_2019_10 = pd.read_csv("October 2019 15-min Rain Data.csv")
data_2019_9 = pd.read_csv("September 2019 15-min Rain Data.csv")
data_2019_8 = pd.read_csv("August 2019 15-min Rain Data.csv")
data_2019_7 = pd.read_csv("July 2019 15-min Rain Data.csv")
data_2019_6 = pd.read_csv("June 2019 15-min Rain Data.csv")
data_2019_5 = pd.read_csv("May 2019 15-min Rain Data (Revised 07-15-19).csv")
data_2019_4 = pd.read_csv("April 2019 15-min Rain Data.csv")

# %%
data_2021['ts'] = data_2021['ts'].astype('datetime64')
data_2021 = data_2021.sort_values(by="Date")
data_2021 = data_2021.set_index("Date")
data_2021_hourly = data_2021.resample("1H").sum()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\arrays\datetimes.py in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object)
#    2084         try:
# -> 2085             values, tz_parsed = conversion.datetime_to_datetime64(data)
#    2086             # If tzaware, these values represent unix timestamps, so we
#
# pandas\_libs\tslibs\conversion.pyx in pandas._libs.tslibs.conversion.datetime_to_datetime64()
#
# TypeError: Unrecognized value type: <class 'str'>
#
# During handling of the above exception, another exception occurred:
#
# ParserError                               Traceback (most recent call last)
# <ipython-input-447-4747ef7b2302> in <module>
# ----> 1 data_2021['ts'] = data_2021['ts'].astype('datetime64')
#       2 data_2021 = data_2021.sort_values(by="Date")
# ...

# %%
data_2021 = pd.read_csv("rainfall (1).csv")
data_2021 = data_2021.iloc[10226:,:]
data_2021
# Out:
#                                                       ts    val src      id  \
# 10226  2021-10-29T14:00:00-04:00/2021-10-29T15:00:00-...  0.023   R  150138
# 10227  2021-10-29T15:00:00-04:00/2021-10-29T16:00:00-...  0.003   R  150138
# 10228  2021-10-29T16:00:00-04:00/2021-10-29T17:00:00-...  0.000   R  150138
# 10229  2021-10-29T17:00:00-04:00/2021-10-29T18:00:00-...  0.000   R  150138
# 10230  2021-10-29T18:00:00-04:00/2021-10-29T19:00:00-...  0.000   R  150138
# ...                                                  ...    ...  ..     ...
# 15381  2021-11-01T07:00:00-04:00/2021-11-01T08:00:00-...  0.000   G       9
# 15382  2021-11-01T08:00:00-04:00/2021-11-01T09:00:00-...  0.000   G       9
# 15383  2021-11-01T09:00:00-04:00/2021-11-01T10:00:00-...  0.000   G       9
# 15384  2021-11-01T10:00:00-04:00/2021-11-01T11:00:00-...  0.000   G       9
# 15385  2021-11-01T11:00:00-04:00/2021-11-01T12:00:00-...  0.000   G       9
#
#         type
# 10226  pixel
# 10227  pixel
# ...

# %%
dti = pd.date_range("2021-04-01", periods=5160, freq="H")

# %%
dti.to_frame
# Out:
# <bound method Index.to_frame of DatetimeIndex(['2021-04-01 00:00:00', '2021-04-01 01:00:00',
#                '2021-04-01 02:00:00', '2021-04-01 03:00:00',
#                '2021-04-01 04:00:00', '2021-04-01 05:00:00',
#                '2021-04-01 06:00:00', '2021-04-01 07:00:00',
#                '2021-04-01 08:00:00', '2021-04-01 09:00:00',
#                ...
#                '2021-11-01 14:00:00', '2021-11-01 15:00:00',
#                '2021-11-01 16:00:00', '2021-11-01 17:00:00',
#                '2021-11-01 18:00:00', '2021-11-01 19:00:00',
#                '2021-11-01 20:00:00', '2021-11-01 21:00:00',
#                '2021-11-01 22:00:00', '2021-11-01 23:00:00'],
#               dtype='datetime64[ns]', length=5160, freq='H')>

# %%
data_2021['Date'] = dti
data_2021
# Out:
#                                                       ts    val src      id  \
# 10226  2021-10-29T14:00:00-04:00/2021-10-29T15:00:00-...  0.023   R  150138
# 10227  2021-10-29T15:00:00-04:00/2021-10-29T16:00:00-...  0.003   R  150138
# 10228  2021-10-29T16:00:00-04:00/2021-10-29T17:00:00-...  0.000   R  150138
# 10229  2021-10-29T17:00:00-04:00/2021-10-29T18:00:00-...  0.000   R  150138
# 10230  2021-10-29T18:00:00-04:00/2021-10-29T19:00:00-...  0.000   R  150138
# ...                                                  ...    ...  ..     ...
# 15381  2021-11-01T07:00:00-04:00/2021-11-01T08:00:00-...  0.000   G       9
# 15382  2021-11-01T08:00:00-04:00/2021-11-01T09:00:00-...  0.000   G       9
# 15383  2021-11-01T09:00:00-04:00/2021-11-01T10:00:00-...  0.000   G       9
# 15384  2021-11-01T10:00:00-04:00/2021-11-01T11:00:00-...  0.000   G       9
# 15385  2021-11-01T11:00:00-04:00/2021-11-01T12:00:00-...  0.000   G       9
#
#         type                Date
# ...

# %%
df = pd.DataFrame(dti)
df.head()
df = data_2021.set_index("Date")
df
# Out:
#                                                                     ts    val  \
# Date
# 2021-04-01 00:00:00  2021-10-29T14:00:00-04:00/2021-10-29T15:00:00-...  0.023
# 2021-04-01 01:00:00  2021-10-29T15:00:00-04:00/2021-10-29T16:00:00-...  0.003
# 2021-04-01 02:00:00  2021-10-29T16:00:00-04:00/2021-10-29T17:00:00-...  0.000
# 2021-04-01 03:00:00  2021-10-29T17:00:00-04:00/2021-10-29T18:00:00-...  0.000
# 2021-04-01 04:00:00  2021-10-29T18:00:00-04:00/2021-10-29T19:00:00-...  0.000
# ...                                                                ...    ...
# 2021-11-01 19:00:00  2021-11-01T07:00:00-04:00/2021-11-01T08:00:00-...  0.000
# 2021-11-01 20:00:00  2021-11-01T08:00:00-04:00/2021-11-01T09:00:00-...  0.000
# 2021-11-01 21:00:00  2021-11-01T09:00:00-04:00/2021-11-01T10:00:00-...  0.000
# 2021-11-01 22:00:00  2021-11-01T10:00:00-04:00/2021-11-01T11:00:00-...  0.000
# 2021-11-01 23:00:00  2021-11-01T11:00:00-04:00/2021-11-01T12:00:00-...  0.000
#
# ...

# %%
df.drop(['ts', 'src','id','type'],axis = 1,inplace=True)
df = df.rename(columns={'val': 'University of Pittsburgh'})
df
# Out:
#                      University of Pittsburgh
# Date
# 2021-04-01 00:00:00                     0.023
# 2021-04-01 01:00:00                     0.003
# 2021-04-01 02:00:00                     0.000
# 2021-04-01 03:00:00                     0.000
# 2021-04-01 04:00:00                     0.000
# ...                                       ...
# 2021-11-01 19:00:00                     0.000
# 2021-11-01 20:00:00                     0.000
# 2021-11-01 21:00:00                     0.000
# 2021-11-01 22:00:00                     0.000
# 2021-11-01 23:00:00                     0.000
#
# [5160 rows x 1 columns]

# %%
hour_daily.append(df)
# Out:
#                      University of Pittsburgh  Highland Park  Nine Mile Run  \
# Date
# 2019-11-01 00:00:00                       0.0            0.0            0.0
# 2019-11-01 01:00:00                       0.0            0.0            0.0
# 2019-11-01 02:00:00                       0.0            0.0            0.0
# 2019-11-01 03:00:00                       0.0            0.0            0.0
# 2019-11-01 04:00:00                       0.0            0.0            0.0
# ...                                       ...            ...            ...
# 2021-11-01 19:00:00                       0.0            NaN            NaN
# 2021-11-01 20:00:00                       0.0            NaN            NaN
# 2021-11-01 21:00:00                       0.0            NaN            NaN
# 2021-11-01 22:00:00                       0.0            NaN            NaN
# 2021-11-01 23:00:00                       0.0            NaN            NaN
#
# ...

# %%
hour_daily
# Out:
#                      University of Pittsburgh  Highland Park  Nine Mile Run  \
# Date
# 2019-11-01 00:00:00                      0.00           0.00           0.00
# 2019-11-01 01:00:00                      0.00           0.00           0.00
# 2019-11-01 02:00:00                      0.00           0.00           0.00
# 2019-11-01 03:00:00                      0.00           0.00           0.00
# 2019-11-01 04:00:00                      0.00           0.00           0.00
# ...                                       ...            ...            ...
# 2021-03-31 19:00:00                      0.00           0.00           0.00
# 2021-03-31 20:00:00                      0.00           0.00           0.00
# 2021-03-31 21:00:00                      0.04           0.04           0.02
# 2021-03-31 22:00:00                      0.03           0.03           0.06
# 2021-03-31 23:00:00                      0.01           0.00           0.00
#
# ...

# %%
+
# Out:
#                      Perry North  ALCOSAN  Shaler  Kennedy Twp.  \
# Date
# 2019-11-01 00:00:00          0.0      0.0     0.0           0.0
# 2019-11-01 01:00:00          0.0      0.0     0.0           0.0
# 2019-11-01 02:00:00          0.0      0.0     0.0           0.0
# 2019-11-01 03:00:00          0.0      0.0     0.0           0.0
# 2019-11-01 04:00:00          0.0      0.0     0.0           0.0
# ...                          ...      ...     ...           ...
# 2019-11-01 19:00:00          NaN      NaN     NaN           NaN
# 2019-11-01 20:00:00          NaN      NaN     NaN           NaN
# 2019-11-01 21:00:00          NaN      NaN     NaN           NaN
# 2019-11-01 22:00:00          NaN      NaN     NaN           NaN
# 2019-11-01 23:00:00          NaN      NaN     NaN           NaN
#
#                      Upper St. Clair  Carnegie  Greentree  Lawrenceville  \
# Date
# 2019-11-01 00:00:00              0.0       0.0        0.0            0.0
# ...

# %%
# Out:
#                      Upitts  University of Pittsburgh
# 0
# 2019-04-01 00:00:00     NaN                       NaN
# 2019-04-01 01:00:00     NaN                       NaN
# 2019-04-01 02:00:00     NaN                       NaN
# 2019-04-01 03:00:00     NaN                       NaN
# 2019-04-01 04:00:00     NaN                       NaN
# ...                     ...                       ...
# 2019-11-01 19:00:00     NaN                       NaN
# 2019-11-01 20:00:00     NaN                       NaN
# 2019-11-01 21:00:00     NaN                       NaN
# 2019-11-01 22:00:00     NaN                       NaN
# 2019-11-01 23:00:00     NaN                       NaN
#
# [5160 rows x 2 columns]
